# %%
import pandas as pd
import numpy as np
import random
import copy
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn.preprocessing import Normalizer

# %%
class myNN():
    def __init__(self, architecture, learning_rate):
        self.architecture = architecture
        self.learning_rate = learning_rate
        self.params = {}
        self.init_layers()
        self.train_loss_history = []
        self.test_loss_history = []
        
    def init_layers(self):
        #np.random.seed(99)
        for index, layer in enumerate(self.architecture):
            layer_index = index + 1
            layer_input_size = layer['input_dim']
            layer_output_size = layer['output_dim']
            self.params['W' + str(layer_index)] = np.random.randn(layer_output_size, layer_input_size)*0.1
            self.params['b' + str(layer_index)] = np.random.randn(layer_output_size, 1)*0.1
            #print(self.params['W'+str(layer_index)].shape)
            #print(self.params['W'+str(layer_index)])
            #print(self.params['b'+str(layer_index)])
            #print("*******")
            
    def sigmoid(self, Z):
        return 1/(1+np.exp(-Z))
    
    def relu(self, Z):
        return np.maximum(0,Z)
    
    def linear(self, Z):
        return Z
    
    def sigmoid_backward(self, dA, Z):
        sig = self.sigmoid(Z)
        return dA*sig*(1-sig)
    
    def relu_backward(self, dA, Z):
        dZ = np.array(dA, copy = True)
        dZ[Z<=0] = 0
        return dZ
    
    def linear_backward(self, dA, Z):
        return dA
    
    def single_layer_FP(self, A_prev, W_curr, b_curr, activation='relu'):
        #print(W_curr.shape)
        #print(A_prev.shape)
        Z_curr = np.dot(W_curr, A_prev) + b_curr
        #print(Z_curr.shape)
        #print("------")
        if activation == 'relu':
            activation_func = self.relu
        elif activation == 'sigmoid':
            activation_func = self.sigmoid
        elif activation == 'linear':
            activation_func = self.linear
        else:
            raise Exception('Non-supported activation function')
        return activation_func(Z_curr), Z_curr
    
    def forward_propagation(self, x):
        memory = {}
        A_curr = x
        for index, layer in enumerate(self.architecture):
            layer_index = index + 1
            A_prev = A_curr
            activation_func = layer['activation']
            W_curr = self.params['W'+str(layer_index)]
            b_curr = self.params['b'+str(layer_index)]
            A_curr, Z_curr = self.single_layer_FP(A_prev, W_curr, b_curr, activation_func)
            memory["A"+str(index)] = A_prev
            memory["Z"+str(layer_index)] = Z_curr
        return A_curr, memory
        
    def get_loss_value(self, y, y_predict):
        #delta = y - y_predict
        #loss = np.dot(delta, delta.T)
        #return np.squeeze(loss)
        return np.power(y_predict - y, 2).sum()
    
    def single_layer_BP(self, dA_curr, W_curr, b_curr, Z_curr, A_prev, activation='relu'):
        if activation == 'relu':
            activation_func = self.relu_backward
        elif activation == 'sigmoid':
            activation_func = self.sigmoid_backward
        elif activation == 'linear':
            activation_func = self.linear_backward
        else:
            raise Exception('Non-supported activation function')
        dZ_curr = activation_func(dA_curr, Z_curr)
        dW_curr = np.dot(dZ_curr, A_prev.T)
        db_curr = np.sum(dZ_curr, axis=1, keepdims=True)
        dA_prev = np.dot(W_curr.T, dZ_curr)
        return dA_prev, dW_curr, db_curr
    
    def back_propagation(self, y_predict, y, memory):
        grads_values = {}
        dA_prev = 2*(y_predict-y)
        #dA_prev = delta * np.ones(y.shape).reshape(1,-1)
        for layer_prev_index, layer in reversed(list(enumerate(self.architecture))):
            layer_cur_index = layer_prev_index+1
            activation_func = layer['activation']
            dA_curr = dA_prev
            A_prev = memory['A' + str(layer_prev_index)]
            Z_curr = memory['Z' + str(layer_cur_index)]
            W_curr = self.params['W'+str(layer_cur_index)]
            b_curr = self.params['b'+str(layer_cur_index)]
            dA_prev, dW_curr, db_curr = self.single_layer_BP(dA_curr, W_curr, b_curr, Z_curr, A_prev, activation_func)
            grads_values['dW'+str(layer_cur_index)] = dW_curr
            grads_values['db'+str(layer_cur_index)] = db_curr
        return grads_values
    
    def update(self, grads_values):
        for index, layer in enumerate(self.architecture):
            layer_idx = index + 1
            self.params["W" + str(layer_idx)] -= learning_rate * grads_values["dW" + str(layer_idx)]        
            self.params["b" + str(layer_idx)] -= learning_rate * grads_values["db" + str(layer_idx)]
    
    def train(self, x_train, y_train, x_test, y_test, epochs, batch_size=16):
        for i in range(epochs):
            x_train, y_train = shuffle(x_train, y_train)
            for j in range(0 ,x_train.shape[0], batch_size):
                start = j
                end = j+batch_size
                if end >= x_train.shape[0]:
                    end = x_train.shape[0]-1
                x_min = x_train[start:end]
                y_min = y_train[start:end]
                y_predict, memory = self.forward_propagation(x_min.T)
                loss = self.get_loss_value(np.array([y_min]), y_predict)
                grads_values = self.back_propagation(y_predict, np.array([y_min]), memory)
                self.update(grads_values)
            y_train_predict = self.predict(x_train.T)
            y_test_predict = self.predict(x_test.T)
            train_loss = self.get_loss_value(np.array([y_train]), y_train_predict)
            test_loss = self.get_loss_value(np.array([y_test]), y_test_predict)
            train_acc = self.accuracy(np.array([y_train]), y_train_predict)
            test_acc = self.accuracy(np.array([y_test]), y_test_predict)
            self.train_loss_history.append(train_loss)
            self.test_loss_history.append(test_loss)
            if (i+1) % 100 == 0:
                print("Eposh : %4d/%d || training loss : %lf || training eval : %lf" % (i+1, epochs, train_loss, train_acc),end=" ")
                print("|| testing loss : %lf || testing eval : %lf" % (test_loss, test_acc))
    
    def show_parm(self):
        print(self.params)
    
    def accuracy(self, y, y_predict):
        power = np.power(y_predict - y, 2).mean()
        return np.sqrt(power)
    
    def predict(self, x):
        y_predict, memory = self.forward_propagation(x)
        return np.squeeze(y_predict)
    
    def get_loss_history(self):
        return self.train_loss_history, self.test_loss_history

# %%
def show_graph(d1, d2, labels, length = 0, locs='upper left'):
    t = range(len(d1))
    if length != 0:
        plt.plot(t[:length],d1[:length], 'r', label=labels[0])
        plt.plot(t[:length],d2[:length], 'b', label=labels[1])
    else:
        plt.plot(t, d1, 'r', label=labels[0])
        plt.plot(t, d2, 'b', label=labels[1])
    plt.legend(loc=locs)
    plt.show()

# %%
def my_split_function(data, label, test_size):
    #random.seed(500)
    #data, label = shuffle(data, label)
    train_len = int(len(data)*(1-test_size))
    return (data[:train_len], data[train_len:], label[:train_len], label[train_len:])

# %%
# https://quantdare.com/create-your-own-deep-learning-framework-using-numpy/
# https://www.itread01.com/feffx.html
# https://towardsdatascience.com/lets-code-a-neural-network-in-plain-numpy-ae7e74410795
nn_architecture = [
    {"input_dim": 16, "output_dim": 32, "activation": "relu"},
    {"input_dim": 32, "output_dim": 16, "activation": "relu"},
    {"input_dim": 16, "output_dim": 8, "activation": "relu"},
    {"input_dim": 8, "output_dim": 1, "activation": "linear"},
]
learning_rate = 0.0000001

# %%
# Orientation category : 2, 3, 4, 5
# Glazing Area Distribution : 0, 1, 2, 3, 4, 5
data = pd.read_csv('energy_efficiency_data.csv')
heating = data.pop('Heating Load')
cooling = data.pop('Cooling Load')

# %%
# for one hot encoding
Orient = pd.get_dummies(data['Orientation'])
Glazing = pd.get_dummies(data['Glazing Area Distribution'])
data = pd.concat([data,pd.get_dummies(data['Orientation'], prefix='Orientation')],axis=1)
data = pd.concat([data,pd.get_dummies(data['Glazing Area Distribution'], prefix='Glazing Area Distribution')],axis=1)
data.drop(['Orientation'],axis=1, inplace=True)
data.drop(['Glazing Area Distribution'],axis=1, inplace=True)

# %%
# split data
#data = Normalizer(norm='l1').fit_transform(data)
x_train, x_test, y_train, y_test = my_split_function(data.to_numpy(), heating.to_numpy(), test_size=0.25)

# %%
model = myNN(nn_architecture, learning_rate)

# %%
model.train(x_train, np.array(y_train), x_test, np.array(y_test), 2000, batch_size=16)
# Out:
# Eposh :  100/2000 || training loss : 17904.716461 || training eval : 5.575354 || testing loss : 6012.360243 || testing eval : 5.595925
# Eposh :  200/2000 || training loss : 17199.638266 || training eval : 5.464475 || testing loss : 5779.720475 || testing eval : 5.486594
# Eposh :  300/2000 || training loss : 16879.502007 || training eval : 5.413381 || testing loss : 5659.045575 || testing eval : 5.429014
# Eposh :  400/2000 || training loss : 15538.505767 || training eval : 5.193898 || testing loss : 5230.396750 || testing eval : 5.219353
# Eposh :  500/2000 || training loss : 14575.975600 || training eval : 5.030459 || testing loss : 4916.209549 || testing eval : 5.060164
# Eposh :  600/2000 || training loss : 13596.133337 || training eval : 4.858436 || testing loss : 4574.222351 || testing eval : 4.880991
# Eposh :  700/2000 || training loss : 12270.947698 || training eval : 4.615596 || testing loss : 4154.494586 || testing eval : 4.651666
# Eposh :  800/2000 || training loss : 10993.765552 || training eval : 4.368798 || testing loss : 3720.572433 || testing eval : 4.402043
# Eposh :  900/2000 || training loss : 9922.170978 || training eval : 4.150421 || testing loss : 3371.661854 || testing eval : 4.190554
# Eposh : 1000/2000 || training loss : 9200.613776 || training eval : 3.996660 || testing loss : 3131.567638 || testing eval : 4.038595
# Eposh : 1100/2000 || training loss : 8732.698035 || training eval : 3.893704 || testing loss : 2980.087437 || testing eval : 3.939707
# Eposh : 1200/2000 || training loss : 8652.976057 || training eval : 3.875891 || testing loss : 2966.122688 || testing eval : 3.930465
# Eposh : 1300/2000 || training loss : 8290.309163 || training eval : 3.793797 || testing loss : 2838.610768 || testing eval : 3.845053
# Eposh : 1400/2000 || training loss : 8199.143771 || training eval : 3.772880 || testing loss : 2807.052909 || testing eval : 3.823620
# Eposh : 1500/2000 || training loss : 8165.054160 || training eval : 3.765029 || testing loss : 2791.692618 || testing eval : 3.813144
# Eposh : 1600/2000 || training loss : 8242.340525 || training eval : 3.782806 || testing loss : 2827.958836 || testing eval : 3.837832
# Eposh : 1700/2000 || training loss : 8361.172287 || training eval : 3.809977 || testing loss : 2874.895150 || testing eval : 3.869549
# Eposh : 1800/2000 || training loss : 8265.719089 || training eval : 3.788167 || testing loss : 2818.815592 || testing eval : 3.831623
# Eposh : 1900/2000 || training loss : 8074.454475 || training eval : 3.744082 || testing loss : 2762.644813 || testing eval : 3.793254
# Eposh : 2000/2000 || training loss : 8194.370444 || training eval : 3.771782 || testing loss : 2796.278666 || testing eval : 3.816275

# %%
y_predict = model.predict(x_train.T)
y_predict = np.squeeze(y_predict)
show_graph(y_predict, y_train, ['y_predict', 'y_train'])

# %%
y_predict = model.predict(x_test.T)
y_predict = np.squeeze(y_predict)
show_graph(y_predict, y_test, ['y_predict', 'y_test'])

# %%
train_loss, test_loss = model.get_loss_history()
t = range(len(train_loss))
show_graph(train_loss, test_loss, ['train_loss', 'test_loss'], locs='upper right')

# %%
# calculate correction
# we need to pop the categorical feature beacuse I think it can't be calculated with corr
data = pd.read_csv('energy_efficiency_data.csv')
data.pop('Orientation')
data.pop('Glazing Area Distribution')
data.corr()
# Out:
#                         # Relative Compactness  Surface Area     Wall Area  \
# # Relative Compactness            1.000000e+00 -9.919015e-01 -2.037817e-01
# Surface Area                     -9.919015e-01  1.000000e+00  1.955016e-01
# Wall Area                        -2.037817e-01  1.955016e-01  1.000000e+00
# Roof Area                        -8.688234e-01  8.807195e-01 -2.923165e-01
# Overall Height                    8.277473e-01 -8.581477e-01  2.809757e-01
# Glazing Area                     -3.209966e-18  3.631399e-17  1.036064e-17
# Heating Load                      6.222722e-01 -6.581202e-01  4.556712e-01
# Cooling Load                      6.343391e-01 -6.729989e-01  4.271170e-01
#
#                            Roof Area  Overall Height  Glazing Area  \
# # Relative Compactness -8.688234e-01    8.277473e-01 -3.209966e-18
# Surface Area            8.807195e-01   -8.581477e-01  3.631399e-17
# Wall Area              -2.923165e-01    2.809757e-01  1.036064e-17
# Roof Area               1.000000e+00   -9.725122e-01  5.581108e-17
# Overall Height         -9.725122e-01    1.000000e+00 -2.481890e-18
# Glazing Area            5.581108e-17   -2.481890e-18  1.000000e+00
# Heating Load           -8.618283e-01    8.894307e-01  2.698410e-01
# Cooling Load           -8.625466e-01    8.957852e-01  2.075050e-01
#
#                         Heating Load  Cooling Load
# # Relative Compactness      0.622272      0.634339
# Surface Area               -0.658120     -0.672999
# Wall Area                   0.455671      0.427117
# Roof Area                  -0.861828     -0.862547
# Overall Height              0.889431      0.895785
# Glazing Area                0.269841      0.207505
# Heating Load                1.000000      0.975862
# Cooling Load                0.975862      1.000000

# %%
# we choose higer corr such about Roof Area, Overall Height, Surface Aread
data.pop('# Relative Compactness')
data.pop('Wall Area')
data.pop('Glazing Area')
data.pop('Cooling Load')
data.pop('Surface Area')
print(data)
heating = data.pop('Heating Load')
# Out:
#      Surface Area  Roof Area  Overall Height  Heating Load
# 0           514.5     110.25             7.0         15.55
# 1           514.5     110.25             7.0         15.55
# 2           514.5     110.25             7.0         15.55
# 3           563.5     122.50             7.0         20.84
# 4           563.5     122.50             7.0         21.46
# ..            ...        ...             ...           ...
# 763         710.5     220.50             3.5         12.43
# 764         735.0     220.50             3.5         14.28
# 765         759.5     220.50             3.5         14.92
# 766         784.0     220.50             3.5         18.19
# 767         808.5     220.50             3.5         16.48
#
# [768 rows x 4 columns]

# %%
nn_architecture = [
    {"input_dim": 3, "output_dim": 32, "activation": "relu"},
    {"input_dim": 32, "output_dim": 16, "activation": "relu"},
    {"input_dim": 16, "output_dim": 8, "activation": "relu"},
    {"input_dim": 8, "output_dim": 1, "activation": "linear"},
]
learning_rate = 0.0000001
x_train, x_test, y_train, y_test = my_split_function(data.to_numpy(), heating.to_numpy(), test_size=0.25)
model = myNN(nn_architecture, learning_rate)

# %%
model.train(x_train, np.array(y_train), x_test, np.array(y_test), 2000, batch_size=16)
# Out:
# Eposh :  100/2000 || training loss : 44648.656554 || training eval : 8.804262 || testing loss : 14878.783440 || testing eval : 8.803049
# Eposh :  200/2000 || training loss : 18346.392304 || training eval : 5.643702 || testing loss : 6160.418948 || testing eval : 5.664408
# Eposh :  300/2000 || training loss : 18060.164825 || training eval : 5.599505 || testing loss : 6063.247832 || testing eval : 5.619557
# Eposh :  400/2000 || training loss : 18160.248419 || training eval : 5.614999 || testing loss : 6115.052555 || testing eval : 5.643512
# Eposh :  500/2000 || training loss : 18780.795787 || training eval : 5.710127 || testing loss : 6277.561022 || testing eval : 5.718009
# Eposh :  600/2000 || training loss : 17603.832205 || training eval : 5.528310 || testing loss : 5932.674045 || testing eval : 5.558718
# Eposh :  700/2000 || training loss : 16533.473384 || training eval : 5.357606 || testing loss : 5555.958844 || testing eval : 5.379339
# Eposh :  800/2000 || training loss : 16123.749166 || training eval : 5.290805 || testing loss : 5426.179337 || testing eval : 5.316141
# Eposh :  900/2000 || training loss : 15834.733047 || training eval : 5.243172 || testing loss : 5314.851088 || testing eval : 5.261323
# Eposh : 1000/2000 || training loss : 15289.303891 || training eval : 5.152080 || testing loss : 5155.016486 || testing eval : 5.181606
# Eposh : 1100/2000 || training loss : 14542.988344 || training eval : 5.024763 || testing loss : 4894.759744 || testing eval : 5.049113
# Eposh : 1200/2000 || training loss : 14195.740774 || training eval : 4.964412 || testing loss : 4791.423872 || testing eval : 4.995531
# Eposh : 1300/2000 || training loss : 13579.361961 || training eval : 4.855438 || testing loss : 4586.346727 || testing eval : 4.887456
# Eposh : 1400/2000 || training loss : 13451.895898 || training eval : 4.832596 || testing loss : 4516.587648 || testing eval : 4.850144
# Eposh : 1500/2000 || training loss : 12352.897366 || training eval : 4.630983 || testing loss : 4177.230641 || testing eval : 4.664377
# Eposh : 1600/2000 || training loss : 12862.921152 || training eval : 4.725617 || testing loss : 4315.585713 || testing eval : 4.740992
# Eposh : 1700/2000 || training loss : 11274.397972 || training eval : 4.424207 || testing loss : 3820.207362 || testing eval : 4.460596
# Eposh : 1800/2000 || training loss : 10966.033840 || training eval : 4.363285 || testing loss : 3700.723082 || testing eval : 4.390285
# Eposh : 1900/2000 || training loss : 10341.423306 || training eval : 4.237200 || testing loss : 3504.949042 || testing eval : 4.272580
# Eposh : 2000/2000 || training loss : 10225.063914 || training eval : 4.213294 || testing loss : 3455.980725 || testing eval : 4.242629

# %%
y_predict = model.predict(x_train.T)
y_predict = np.squeeze(y_predict)
show_graph(y_predict, y_train, ['y_predict', 'y_train'])

# %%
y_predict = model.predict(x_test.T)
y_predict = np.squeeze(y_predict)
show_graph(y_predict, y_test, ['y_predict', 'y_test'])

# %%
train_loss, test_loss = model.get_loss_history()
t = range(len(train_loss))
show_graph(train_loss, test_loss, ['train_loss', 'test_loss'], locs='upper right')

# %%
data = pd.read_csv('energy_efficiency_data.csv')
data.pop('Orientation')
data.pop('Glazing Area Distribution')
data.pop('Roof Area')
data.pop('Surface Area')
data.pop('Overall Height')
data.pop('Cooling Load')
print(data)
heating = data.pop('Heating Load')
# Out:
#      # Relative Compactness  Wall Area  Glazing Area  Heating Load
# 0                      0.98      294.0           0.0         15.55
# 1                      0.98      294.0           0.0         15.55
# 2                      0.98      294.0           0.0         15.55
# 3                      0.90      318.5           0.0         20.84
# 4                      0.90      318.5           0.0         21.46
# ..                      ...        ...           ...           ...
# 763                    0.71      269.5           0.4         12.43
# 764                    0.69      294.0           0.4         14.28
# 765                    0.66      318.5           0.4         14.92
# 766                    0.64      343.0           0.4         18.19
# 767                    0.62      367.5           0.4         16.48
#
# [768 rows x 4 columns]

# %%
nn_architecture = [
    {"input_dim": 3, "output_dim": 32, "activation": "relu"},
    {"input_dim": 32, "output_dim": 16, "activation": "relu"},
    {"input_dim": 16, "output_dim": 8, "activation": "relu"},
    {"input_dim": 8, "output_dim": 1, "activation": "linear"},
]
learning_rate = 0.0000001
x_train, x_test, y_train, y_test = my_split_function(data.to_numpy(), heating.to_numpy(), test_size=0.25)
model = myNN(nn_architecture, learning_rate)

# %%
model.train(x_train, np.array(y_train), x_test, np.array(y_test), 5000, batch_size=16)
# Out:
# Eposh :  100/5000 || training loss : 47738.416196 || training eval : 9.103801 || testing loss : 15950.187784 || testing eval : 9.114488
# Eposh :  200/5000 || training loss : 47736.853243 || training eval : 9.103652 || testing loss : 15949.794739 || testing eval : 9.114376
# Eposh :  300/5000 || training loss : 47739.821342 || training eval : 9.103935 || testing loss : 15950.047217 || testing eval : 9.114448
# Eposh :  400/5000 || training loss : 47740.918642 || training eval : 9.104040 || testing loss : 15950.129979 || testing eval : 9.114472
# Eposh :  500/5000 || training loss : 47731.870118 || training eval : 9.103177 || testing loss : 15949.145293 || testing eval : 9.114190
# Eposh :  600/5000 || training loss : 47730.854974 || training eval : 9.103080 || testing loss : 15948.863865 || testing eval : 9.114110
# Eposh :  700/5000 || training loss : 47731.425620 || training eval : 9.103135 || testing loss : 15949.876781 || testing eval : 9.114399
# Eposh :  800/5000 || training loss : 47728.865093 || training eval : 9.102890 || testing loss : 15948.320217 || testing eval : 9.113955
# Eposh :  900/5000 || training loss : 47737.110572 || training eval : 9.103677 || testing loss : 15948.720035 || testing eval : 9.114069
# Eposh : 1000/5000 || training loss : 47726.806029 || training eval : 9.102694 || testing loss : 15947.283978 || testing eval : 9.113658
# Eposh : 1100/5000 || training loss : 47728.815322 || training eval : 9.102886 || testing loss : 15949.374010 || testing eval : 9.114256
# Eposh : 1200/5000 || training loss : 47724.715401 || training eval : 9.102495 || testing loss : 15946.867469 || testing eval : 9.113539
# Eposh : 1300/5000 || training loss : 47723.929922 || training eval : 9.102420 || testing loss : 15946.171808 || testing eval : 9.113341
# Eposh : 1400/5000 || training loss : 47723.749405 || training eval : 9.102403 || testing loss : 15945.714201 || testing eval : 9.113210
# Eposh : 1500/5000 || training loss : 47723.584619 || training eval : 9.102387 || testing loss : 15945.411457 || testing eval : 9.113123
# Eposh : 1600/5000 || training loss : 47721.032882 || training eval : 9.102143 || testing loss : 15945.103504 || testing eval : 9.113035
# Eposh : 1700/5000 || training loss : 47720.286214 || training eval : 9.102072 || testing loss : 15945.894065 || testing eval : 9.113261
# Eposh : 1800/5000 || training loss : 47718.970974 || training eval : 9.101947 || testing loss : 15945.311134 || testing eval : 9.113095
# Eposh : 1900/5000 || training loss : 47717.942618 || training eval : 9.101849 || testing loss : 15944.969313 || testing eval : 9.112997
# Eposh : 2000/5000 || training loss : 47721.680070 || training eval : 9.102205 || testing loss : 15947.392627 || testing eval : 9.113690
# Eposh : 2100/5000 || training loss : 47715.720160 || training eval : 9.101637 || testing loss : 15944.090190 || testing eval : 9.112746
# Eposh : 2200/5000 || training loss : 47714.774679 || training eval : 9.101547 || testing loss : 15943.848208 || testing eval : 9.112677
# Eposh : 2300/5000 || training loss : 47715.829981 || training eval : 9.101647 || testing loss : 15942.757773 || testing eval : 9.112365
# Eposh : 2400/5000 || training loss : 47712.533955 || training eval : 9.101333 || testing loss : 15942.917692 || testing eval : 9.112411
# Eposh : 2500/5000 || training loss : 47712.615350 || training eval : 9.101341 || testing loss : 15943.544230 || testing eval : 9.112590
# Eposh : 2600/5000 || training loss : 47713.706505 || training eval : 9.101445 || testing loss : 15941.863446 || testing eval : 9.112109
# Eposh : 2700/5000 || training loss : 47711.096460 || training eval : 9.101196 || testing loss : 15941.363936 || testing eval : 9.111967
# Eposh : 2800/5000 || training loss : 47708.642141 || training eval : 9.100962 || testing loss : 15941.820369 || testing eval : 9.112097
# Eposh : 2900/5000 || training loss : 47716.090667 || training eval : 9.101672 || testing loss : 15946.045781 || testing eval : 9.113305
# Eposh : 3000/5000 || training loss : 47709.210641 || training eval : 9.101016 || testing loss : 15942.854722 || testing eval : 9.112393
# Eposh : 3100/5000 || training loss : 47705.389040 || training eval : 9.100651 || testing loss : 15940.248094 || testing eval : 9.111648
# Eposh : 3200/5000 || training loss : 47715.156502 || training eval : 9.101583 || testing loss : 15945.987944 || testing eval : 9.113288
# Eposh : 3300/5000 || training loss : 47703.317130 || training eval : 9.100454 || testing loss : 15939.754440 || testing eval : 9.111507
# Eposh : 3400/5000 || training loss : 47703.361294 || training eval : 9.100458 || testing loss : 15940.461278 || testing eval : 9.111709
# Eposh : 3500/5000 || training loss : 47702.980426 || training eval : 9.100422 || testing loss : 15940.530956 || testing eval : 9.111729
# Eposh : 3600/5000 || training loss : 47700.299639 || training eval : 9.100166 || testing loss : 15938.566811 || testing eval : 9.111167
# Eposh : 3700/5000 || training loss : 47699.961236 || training eval : 9.100134 || testing loss : 15939.211819 || testing eval : 9.111352
# Eposh : 3800/5000 || training loss : 47704.050779 || training eval : 9.100524 || testing loss : 15938.260624 || testing eval : 9.111080
# Eposh : 3900/5000 || training loss : 47699.599531 || training eval : 9.100099 || testing loss : 15937.392421 || testing eval : 9.110832
# Eposh : 4000/5000 || training loss : 47696.388025 || training eval : 9.099793 || testing loss : 15937.105359 || testing eval : 9.110750
# Eposh : 4100/5000 || training loss : 47696.018615 || training eval : 9.099758 || testing loss : 15936.652482 || testing eval : 9.110620
# Eposh : 4200/5000 || training loss : 47694.293629 || training eval : 9.099593 || testing loss : 15937.008218 || testing eval : 9.110722
# Eposh : 4300/5000 || training loss : 47698.390068 || training eval : 9.099984 || testing loss : 15936.475792 || testing eval : 9.110570
# Eposh : 4400/5000 || training loss : 47692.970902 || training eval : 9.099467 || testing loss : 15936.960996 || testing eval : 9.110708
# Eposh : 4500/5000 || training loss : 47691.948698 || training eval : 9.099369 || testing loss : 15936.622577 || testing eval : 9.110612
# Eposh : 4600/5000 || training loss : 47691.522401 || training eval : 9.099329 || testing loss : 15936.680511 || testing eval : 9.110628
# Eposh : 4700/5000 || training loss : 47689.194912 || training eval : 9.099107 || testing loss : 15935.321575 || testing eval : 9.110240
# Eposh : 4800/5000 || training loss : 47694.824060 || training eval : 9.099644 || testing loss : 15935.083916 || testing eval : 9.110172
# Eposh : 4900/5000 || training loss : 47687.768702 || training eval : 9.098971 || testing loss : 15933.967382 || testing eval : 9.109853
# Eposh : 5000/5000 || training loss : 47686.652736 || training eval : 9.098864 || testing loss : 15934.795684 || testing eval : 9.110089

# %%
y_predict = model.predict(x_train.T)
y_predict = np.squeeze(y_predict)
show_graph(y_predict, y_train, ['y_predict', 'y_train'])

# %%
y_predict = model.predict(x_test.T)
y_predict = np.squeeze(y_predict)
show_graph(y_predict, y_test, ['y_predict', 'y_test'])

# %%
train_loss, test_loss = model.get_loss_history()
t = range(len(train_loss))
show_graph(train_loss, test_loss, ['train_loss', 'test_loss'], locs='upper right')

# %%
# if we think the cacategorical features are also import feature
data = pd.read_csv('energy_efficiency_data.csv')
Orient = pd.get_dummies(data['Orientation'])
Glazing = pd.get_dummies(data['Glazing Area Distribution'])
data = pd.concat([data,pd.get_dummies(data['Orientation'], prefix='Orientation')],axis=1)
data = pd.concat([data,pd.get_dummies(data['Glazing Area Distribution'], prefix='Glazing Area Distribution')],axis=1)
data.drop(['Orientation'],axis=1, inplace=True)
data.drop(['Glazing Area Distribution'],axis=1, inplace=True)
data.pop('# Relative Compactness')
data.pop('Wall Area')
data.pop('Glazing Area')
data.pop('Cooling Load')
heating = data.pop('Heating Load')

# %%
nn_architecture = [
    {"input_dim": 13, "output_dim": 32, "activation": "relu"},
    {"input_dim": 32, "output_dim": 16, "activation": "relu"},
    {"input_dim": 16, "output_dim": 8, "activation": "relu"},
    {"input_dim": 8, "output_dim": 1, "activation": "linear"},
]
learning_rate = 0.0000001
x_train, x_test, y_train, y_test = my_split_function(data.to_numpy(), heating.to_numpy(), test_size=0.25)
model = myNN(nn_architecture, learning_rate)

# %%
model.train(x_train, np.array(y_train), x_test, np.array(y_test), 2000, batch_size=16)
# Out:
# Eposh :  100/2000 || training loss : 73526.252166 || training eval : 11.298219 || testing loss : 24527.842750 || testing eval : 11.302618
# Eposh :  200/2000 || training loss : 17710.893249 || training eval : 5.545095 || testing loss : 5940.017893 || testing eval : 5.562157
# Eposh :  300/2000 || training loss : 16455.747551 || training eval : 5.344998 || testing loss : 5514.576336 || testing eval : 5.359268
# Eposh :  400/2000 || training loss : 15385.196714 || training eval : 5.168212 || testing loss : 5181.811339 || testing eval : 5.195055
# Eposh :  500/2000 || training loss : 14624.543760 || training eval : 5.038832 || testing loss : 4926.274119 || testing eval : 5.065341
# Eposh :  600/2000 || training loss : 15085.760335 || training eval : 5.117671 || testing loss : 5046.131248 || testing eval : 5.126591
# Eposh :  700/2000 || training loss : 13158.972830 || training eval : 4.779690 || testing loss : 4446.160821 || testing eval : 4.812181
# Eposh :  800/2000 || training loss : 12149.058639 || training eval : 4.592615 || testing loss : 4099.710024 || testing eval : 4.620893
# Eposh :  900/2000 || training loss : 11668.637151 || training eval : 4.500894 || testing loss : 3952.991021 || testing eval : 4.537455
# Eposh : 1000/2000 || training loss : 11476.570362 || training eval : 4.463698 || testing loss : 3899.605661 || testing eval : 4.506711
# Eposh : 1100/2000 || training loss : 10403.026158 || training eval : 4.249801 || testing loss : 3531.132995 || testing eval : 4.288510
# Eposh : 1200/2000 || training loss : 9867.387213 || training eval : 4.138947 || testing loss : 3340.340636 || testing eval : 4.171044
# Eposh : 1300/2000 || training loss : 9467.669226 || training eval : 4.054248 || testing loss : 3217.650969 || testing eval : 4.093727
# Eposh : 1400/2000 || training loss : 9156.635328 || training eval : 3.987096 || testing loss : 3112.626260 || testing eval : 4.026363
# Eposh : 1500/2000 || training loss : 8979.281660 || training eval : 3.948295 || testing loss : 3058.268445 || testing eval : 3.991050
# Eposh : 1600/2000 || training loss : 8771.734684 || training eval : 3.902397 || testing loss : 2987.371438 || testing eval : 3.944519
# Eposh : 1700/2000 || training loss : 8956.786882 || training eval : 3.943346 || testing loss : 3035.621517 || testing eval : 3.976246
# Eposh : 1800/2000 || training loss : 8550.055659 || training eval : 3.852771 || testing loss : 2907.881865 || testing eval : 3.891686
# Eposh : 1900/2000 || training loss : 8583.273658 || training eval : 3.860248 || testing loss : 2934.940684 || testing eval : 3.909751
# Eposh : 2000/2000 || training loss : 8405.476895 || training eval : 3.820058 || testing loss : 2859.900376 || testing eval : 3.859445

# %%
y_predict = model.predict(x_train.T)
y_predict = np.squeeze(y_predict)
show_graph(y_predict, y_train, ['y_predict', 'y_train'])

# %%
y_predict = model.predict(x_test.T)
y_predict = np.squeeze(y_predict)
show_graph(y_predict, y_test, ['y_predict', 'y_test'])

# %%
train_loss, test_loss = model.get_loss_history()
t = range(len(train_loss))
show_graph(train_loss, test_loss, ['train_loss', 'test_loss'], locs='upper right')
